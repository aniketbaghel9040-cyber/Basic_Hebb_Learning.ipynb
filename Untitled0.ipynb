# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketbaghel9040-cyber/Basic_Hebb_Learning.ipynb/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

X = "Hello! My name is Aniket."
w = tokenizer.tokenize(X)

print(w)
# Out:
# ['Hello', '!', 'My', 'name', 'is', 'Aniket', '.']
